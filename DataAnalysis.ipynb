# %%
#imports 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("diamonds.csv")
print(df.index)
print("All columns are")
ai=0
for i in df:
    print(ai,i)
    ai+=1
# Out:
# RangeIndex(start=0, stop=53940, step=1)
# All columns are
# 0 carat
# 1 cut
# 2 color
# 3 clarity
# 4 depth
# 5 table
# 6 x
# 7 y
# 8 z
# 9 price

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.head(n=10)
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43    326
# 1   0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31    326
# 2   0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31    327
# 3   0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63    334
# 4   0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75    335
# 5   0.24  Very Good     J    VVS2   62.8   57.0  3.94  3.96  2.48    336
# 6   0.24  Very Good     I    VVS1   62.3   57.0  3.95  3.98  2.47    336
# 7   0.26  Very Good     H     SI1   61.9   55.0  4.07  4.11  2.53    337
# 8   0.22       Fair     E     VS2   65.1   61.0  3.87  3.78  2.49    337
# 9   0.23  Very Good     H     VS1   59.4   61.0  4.00  4.05  2.39    338

# %%
df.sample(n=10)
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 13562   1.96       Fair     F      I1   66.6   60.0  7.59  7.56  5.04   5554
# 48494   0.52      Ideal     F     VS2   61.5   56.0  5.19  5.21  3.20   1981
# 25489   2.20      Ideal     I     SI2   62.2   56.0  8.34  8.29  5.18  14277
# 19171   1.28  Very Good     E     SI1   59.8   59.1  6.99  7.05  4.21   7927
# 29885   0.30      Ideal     E     VS1   61.7   57.0  4.28  4.31  2.65    710
# 30618   0.34    Premium     I     SI1   62.7   58.0  4.40  4.43  2.77    447
# 14096   1.23    Premium     I     SI1   62.0   57.0  6.91  6.83  4.26   5717
# 44387   0.41      Ideal     D    VVS1   62.2   56.0  4.80  4.78  2.98   1582
# 41089   0.41      Ideal     F    VVS2   62.6   55.0  4.76  4.73  2.97   1192
# 44316   0.32      Ideal     J      IF   61.0   57.0  4.42  4.46  2.71    521

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   x        53940 non-null  float64
#  7   y        53940 non-null  float64
#  8   z        53940 non-null  float64
#  9   price    53940 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df.isnull()
# Out:
#        carat    cut  color  clarity  depth  table      x      y      z  price
# 0      False  False  False    False  False  False  False  False  False  False
# 1      False  False  False    False  False  False  False  False  False  False
# 2      False  False  False    False  False  False  False  False  False  False
# 3      False  False  False    False  False  False  False  False  False  False
# 4      False  False  False    False  False  False  False  False  False  False
# ...      ...    ...    ...      ...    ...    ...    ...    ...    ...    ...
# 53935  False  False  False    False  False  False  False  False  False  False
# 53936  False  False  False    False  False  False  False  False  False  False
# 53937  False  False  False    False  False  False  False  False  False  False
# 53938  False  False  False    False  False  False  False  False  False  False
# 53939  False  False  False    False  False  False  False  False  False  False
#
# [53940 rows x 10 columns]

# %%
print(df.isnull().sum())
print('no null values')
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64
# no null values

# %%
df.describe()
# Out:
#               carat         depth         table             x             y  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184      5.731157      5.734526
# std        0.474011      1.432621      2.234491      1.121761      1.142135
# min        0.200000     43.000000     43.000000      0.000000      0.000000
# 25%        0.400000     61.000000     56.000000      4.710000      4.720000
# 50%        0.700000     61.800000     57.000000      5.700000      5.710000
# 75%        1.040000     62.500000     59.000000      6.540000      6.540000
# max        5.010000     79.000000     95.000000     10.740000     58.900000
#
#                   z         price
# count  53940.000000  53940.000000
# mean       3.538734   3932.799722
# std        0.705699   3989.439738
# min        0.000000    326.000000
# 25%        2.910000    950.000000
# 50%        3.530000   2401.000000
# 75%        4.040000   5324.250000
# ...

# %%
# Removing null values
df = df.dropna()
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   x        53940 non-null  float64
#  7   y        53940 non-null  float64
#  8   z        53940 non-null  float64
#  9   price    53940 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB
# None

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z',
#        'price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   x        53940 non-null  float64
#  7   y        53940 non-null  float64
#  8   z        53940 non-null  float64
#  9   price    53940 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
# Plotting only useful columns
grid = sns.pairplot(df,corner=True)

# %%
# For saving the plot
'''


grid.savefig('Diamonds.png', dpi=300, bbox_inches='tight')


'''
print('This plot gives us a rough idea of the data')
# Out:
# This plot gives us a rough idea of the data

# %%
plt.figure(figsize=(20,18))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'x', 'y', 'z',
#        'price'],
#       dtype='object')

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')

# %%
churnplot = sns.pairplot(
            df,
            vars=df.select_dtypes(include='number').columns,
            hue='cut',
            plot_kws={'alpha':0.5},
            corner = True
            )

# %%
'''

churnplot.savefig('DiamondCutCat.png', dpi=300, bbox_inches='tight')

'''

# %%
# Boxplot for outlier detection

numerical_cols = df.select_dtypes(include='number').columns

plt.figure(figsize=(20, 16))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(3, 3, i)
    sns.boxplot(data=df, y=col, color='skyblue')
    plt.title(f'Boxplot of {col}')

plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   x        53940 non-null  float64
#  7   y        53940 non-null  float64
#  8   z        53940 non-null  float64
#  9   price    53940 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
# Checking stats of every category
# 1 is good , 2 is average , 3 is bad
adf = df[df['cut'] == "Ideal"]
adf.describe()
# Out:
#               carat         depth         table             x             y  \
# count  21551.000000  21551.000000  21551.000000  21551.000000  21551.000000
# mean       0.702837     61.709401     55.951668      5.507451      5.520080
# std        0.432876      0.718539      1.246423      1.064210      1.074495
# min        0.200000     43.000000     43.000000      0.000000      0.000000
# 25%        0.350000     61.300000     55.000000      4.540000      4.550000
# 50%        0.540000     61.800000     56.000000      5.250000      5.260000
# 75%        1.010000     62.200000     57.000000      6.440000      6.445000
# max        3.500000     66.700000     63.000000      9.650000     31.800000
#
#                   z         price
# count  21551.000000  21551.000000
# mean       3.401448   3457.541970
# std        0.657648   3808.401172
# min        0.000000    326.000000
# 25%        2.800000    878.000000
# 50%        3.230000   1810.000000
# 75%        3.980000   4678.500000
# ...

# %%
bdf = df[df['cut'] == "Fair"]
bdf.describe()
# Out:
#              carat        depth        table            x            y  \
# count  1610.000000  1610.000000  1610.000000  1610.000000  1610.000000
# mean      1.046137    64.041677    59.053789     6.246894     6.182652
# std       0.516404     3.643428     3.946261     0.964317     0.956380
# min       0.220000    43.000000    49.000000     0.000000     0.000000
# 25%       0.700000    64.400000    56.000000     5.630000     5.570000
# 50%       1.000000    65.000000    58.000000     6.175000     6.100000
# 75%       1.200000    65.900000    61.000000     6.700000     6.640000
# max       5.010000    79.000000    95.000000    10.740000    10.540000
#
#                  z         price
# count  1610.000000   1610.000000
# mean      3.982770   4358.757764
# std       0.651638   3560.386612
# min       0.000000    337.000000
# 25%       3.610000   2050.250000
# 50%       3.970000   3282.000000
# 75%       4.280000   5205.500000
# max       6.980000  18574.000000

# %%
cdf = df[df['cut'] == "Good"]
cdf.describe()
# Out:
#              carat        depth        table            x            y  \
# count  4906.000000  4906.000000  4906.000000  4906.000000  4906.000000
# mean      0.849185    62.365879    58.694639     5.838785     5.850744
# std       0.454054     2.169374     2.851300     1.057301     1.051535
# min       0.230000    54.300000    51.000000     0.000000     0.000000
# 25%       0.500000    61.300000    56.000000     5.020000     5.020000
# 50%       0.820000    63.400000    58.000000     5.980000     5.990000
# 75%       1.010000    63.800000    61.000000     6.420000     6.440000
# max       3.010000    67.000000    66.000000     9.440000     9.380000
#
#                  z         price
# count  4906.000000   4906.000000
# mean      3.639507   3928.864452
# std       0.654893   3681.589584
# min       0.000000    327.000000
# 25%       3.070000   1145.000000
# 50%       3.700000   3050.500000
# 75%       4.030000   5028.000000
# max       5.790000  18788.000000

# %%
ddf = df[df['cut'] == "Very Good"]
ddf.describe()
# Out:
#               carat         depth         table             x             y  \
# count  12082.000000  12082.000000  12082.000000  12082.000000  12082.000000
# mean       0.806381     61.818275     57.956150      5.740696      5.770026
# std        0.459435      1.378631      2.121448      1.100839      1.102924
# min        0.200000     56.800000     44.000000      0.000000      0.000000
# 25%        0.410000     60.900000     56.000000      4.750000      4.770000
# 50%        0.710000     62.100000     58.000000      5.740000      5.770000
# 75%        1.020000     62.900000     59.000000      6.470000      6.510000
# max        4.000000     64.900000     66.000000     10.010000      9.940000
#
#                   z         price
# count  12082.000000  12082.000000
# mean       3.559801   3981.759891
# std        0.730228   3935.862161
# min        0.000000    336.000000
# 25%        2.950000    912.000000
# 50%        3.560000   2648.000000
# 75%        4.020000   5372.750000
# ...

# %%
edf = df[df['cut'] == "Premium"]
edf.describe()
# Out:
#               carat         depth         table             x             y  \
# count  13791.000000  13791.000000  13791.000000  13791.000000  13791.000000
# mean       0.891955     61.264673     58.746095      5.973887      5.944879
# std        0.515262      1.158815      1.478573      1.188252      1.259751
# min        0.200000     58.000000     51.000000      0.000000      0.000000
# 25%        0.410000     60.500000     58.000000      4.800000      4.790000
# 50%        0.860000     61.400000     59.000000      6.110000      6.060000
# 75%        1.200000     62.200000     60.000000      6.800000      6.760000
# max        4.010000     63.000000     62.000000     10.140000     58.900000
#
#                   z         price
# count  13791.000000  13791.000000
# mean       3.647124   4584.257704
# std        0.731161   4349.204961
# min        0.000000    326.000000
# 25%        2.940000   1046.000000
# 50%        3.720000   3185.000000
# 75%        4.160000   6296.000000
# ...

# %%
for i in df.select_dtypes(include=['object', 'string']):
    counts = df[i].value_counts()
    print(counts)
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64
# color
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: count, dtype: int64
# clarity
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: count, dtype: int64
